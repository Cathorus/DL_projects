# %% [markdown]
# 1. [Reading an image file and converting it to a numpy array](#1)
# 1. [Resizing the image using Pillow library](#2)
# 1. [Converting RGB images to Grayscale image using OpenCV](#3)

# %%
# getting an image using web get

# !wget 'https://tractive.com/blog/wp-content/uploads/2016/04/puppy-care-guide-for-new-parents.jpg'
# Out:
# --2023-05-02 20:54:43--  https://tractive.com/blog/wp-content/uploads/2016/04/puppy-care-guide-for-new-parents.jpg
# Resolving tractive.com (tractive.com)... 108.156.152.14, 108.156.152.26, 108.156.152.102, ...
# Connecting to tractive.com (tractive.com)|108.156.152.14|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 113570 (111K) [image/jpeg]
# Saving to: ‘puppy-care-guide-for-new-parents.jpg’
#
# puppy-care-guide-fo 100%[===================>] 110.91K  --.-KB/s    in 0.02s
#
# 2023-05-02 20:54:43 (4.94 MB/s) - ‘puppy-care-guide-for-new-parents.jpg’ saved [113570/113570]

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# %% [markdown]
# <a id = "1"></a><br>
# # Reading an image file and converting it to a numpy array

# %%
# loading an image through matplotlib.image module

img = mpimg.imread('puppy-care-guide-for-new-parents.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
print(img.shape)
# Out:
# (1365, 2048, 3)

# %%
print(img)
# Out:
# [[[147 182   0]
#   [147 182   0]
#   [147 182   0]
#   ...
#   [128 148   0]
#   [128 148   0]
#   [128 148   0]]
#
#  [[146 181   0]
#   [146 181   0]
#   [147 182   0]
#   ...
#   [128 148   0]
#   [128 148   0]
#   [128 148   0]]
#
#  [[145 180   0]
#   [145 180   0]
#   [145 180   0]
#   ...
#   [128 148   0]
#   [128 148   0]
#   [128 148   0]]
#
#  ...
#
#  [[ 76  69  25]
#   [ 76  69  25]
#   [ 75  68  24]
#   ...
#   [135 106  38]
#   [135 106  38]
#   [135 106  38]]
#
#  [[ 76  69  25]
#   [ 76  69  25]
#   [ 75  68  24]
#   ...
#   [135 106  38]
#   [135 106  38]
#   [135 106  38]]
#
#  [[ 76  69  25]
#   [ 76  69  25]
#   [ 75  68  24]
#   ...
#   [135 106  38]
#   [135 106  38]
#   [135 106  38]]]

# %%
# displaying the image from numpy array

img_plot = plt.imshow(img)
plt.show()

# %% [markdown]
# <a id = "2"></a><br>
# # Resizing the image using Pillow library

# %%
from PIL import Image

# %%
img = Image.open('puppy-care-guide-for-new-parents.jpg')
img_resized = img.resize((200, 200))

# %%
img_resized.save('dog_image_resized.jpg')

# %%
# displaying the image from numpy array

img_res = mpimg.imread('puppy-care-guide-for-new-parents.jpg')
img_res_plot = plt.imshow(img_res)
plt.show()

# %% [markdown]
# <a id = "3"></a><br>
# # Converting RGB images to Grayscale image using OpenCV

# %%
# importing OpenCV library
import cv2

# %%
img = cv2.imread('puppy-care-guide-for-new-parents.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (1365, 2048, 3)

# %%
grayscale_image = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)

# %%
type(grayscale_image)
# Out:
# numpy.ndarray

# %%
grayscale_image.shape
# Out:
# (1365, 2048)

# %%
# saving the grayscale image
cv2.imwrite('dog_grayscale_image.jpg', grayscale_image)
# Out:
# True
